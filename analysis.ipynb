# %%
import pandas as pd

# %%
df = pd.read_csv('finn_data_cleaned.csv')

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             116 non-null    object
#  1   address         115 non-null    object
#  2   total_price     115 non-null    float64
#  3   asking_price    116 non-null    int64
#  4   m2              116 non-null    int64
#  5   rooms           103 non-null    float64
#  6   bedrooms        114 non-null    float64
#  7   apartment_type  116 non-null    object
#  8   TBA             109 non-null    float64
#  9   BRA_i           110 non-null    float64
#  10  BRA_e           103 non-null    float64
#  11  byggeår         99 non-null     float64
#  12  fellesgjeld     78 non-null     float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 11.9+ KB
